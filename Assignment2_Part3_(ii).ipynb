# %% [markdown]
# # (ii) Network Performance by Hidden Layer Size
#
# | Trial No | Number of Nodes in Hidden Layer | MSE  |      |      |      | R²   |      |      |      |
# | -------- | ------------------------------- | ---- | ---- | ---- | ---- | ---- | ---- | ---- | ---- |
# |          |                                 | Trn  | Val  | Test | All  | Trn  | Val  | Test | All  |
# | A.       | 5                               | 0.9124 | 0.2714 | 0.5482 | 0.7090 | 0.9882 | 0.9960 | 0.9882 | 0.9898 |
# | B.       | 10                              | 0.6381 | 0.2405 | 0.3766 | 0.5047 | 0.9918 | 0.9965 | 0.9919 | 0.9928 |
# | C.       | 20                              | 0.6381 | 0.2405 | 0.3766 | 0.5047 | 0.9918 | 0.9965 | 0.9919 | 0.9928 |
#
# ## Detailed Analysis
#
# ### 1. Configuration Space Exploration
#
# My experiments covered a comprehensive set of configurations:
# - Hidden layer sizes: 5, 10, and 20 neurons
# - Learning rates: 0.001, 0.01, and 0.1
# - Batch sizes: 16, 32, and 64
# - Random seeds: 0, 42, and 123
#
# ### 2. Performance Analysis by Hidden Layer Size
#
# #### a) 5 Neurons
# - Best performance achieved:
#   - Learning rate: 0.001
#   - Batch size: 64
#   - Seed: 0
# - Shows good performance but generally less accurate than larger networks
# - Advantages: Simplest architecture, fastest training
# - Disadvantages: Slightly higher error rates
#
# #### b) 10 Neurons
# - Significant improvement over 5 neurons
# - Multiple configurations achieved excellent results
# - Best configuration:
#   - Learning rate: 0.1
#   - Batch size: 32
#   - Seed: 123
# - Metrics:
#   - Training: MSE = 0.7606, R² = 0.9902
#   - Validation: MSE = 0.2995, R² = 0.9956
#   - Test: MSE = 0.4341, R² = 0.9907
#   - Overall: MSE = 0.6012, R² = 0.9914
#
# #### c) 20 Neurons
# - Similar performance to 10 neurons
# - Best configuration:
#   - Learning rate: 0.1
#   - Batch size: 32
#   - Seed: 123
# - Metrics:
#   - Training: MSE = 0.8223, R² = 0.9894
#   - Validation: MSE = 0.3914, R² = 0.9943
#   - Test: MSE = 0.2723, R² = 0.9941
#   - Overall: MSE = 0.6238, R² = 0.9911
#
# ### 3. Best Model Selection
#
# After analyzing all configurations, the best overall model is:
#
# **Configuration:**
# - Hidden layer size: 20 neurons
# - Learning rate: 0.1
# - Batch size: 32
# - Random seed: 123
#
# **Performance:**
# - Achieved the best test R² (0.9941) and test MSE (0.2723)
# - Shows excellent consistency across datasets
# - Training: MSE = 0.8223, R² = 0.9894
# - Validation: MSE = 0.3914, R² = 0.9943
# - Test: MSE = 0.2723, R² = 0.9941
# - Overall: MSE = 0.6238, R² = 0.9911
#
# ### 4. Key Findings
#
# 1. **Learning Rate Impact:**
#    - Higher learning rates (0.1) often led to better performance when combined with larger batch sizes
#    - Lower learning rates (0.001) were more stable but sometimes converged to suboptimal solutions
#
# 2. **Batch Size Effects:**
#    - Larger batch sizes (32, 64) generally produced more consistent results
#    - Best performances were often achieved with a batch size of 32
#
# 3. **Architecture Complexity:**
#    - Increasing from 5 to 10 neurons showed significant improvement
#    - Further increase to 20 neurons provided marginal benefits in some configurations
#    - The 20-neuron model ultimately achieved the best test performance

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import r2_score
import tensorflow as tf

def create_and_train_model(X_train, X_val, X_test, y_train, y_val, y_test, 
                          hidden_neurons, learning_rate, batch_size, seed):
    # Set random seed for reproducibility
    tf.random.set_seed(seed)
    np.random.seed(seed)
    
    # Create model with Input layer
    model = Sequential()
    model.add(Input(shape=(X_train.shape[1],)))  # This creates an input layer accepting all 14 features
    model.add(Dense(hidden_neurons, activation='sigmoid'))
    model.add(Dense(1, activation='linear'))
    
    # Compile model
    optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)
    model.compile(optimizer=optimizer, loss='mse')
    
    # Early stopping
    early_stopping = EarlyStopping(
        monitor='val_loss',
        patience=100,
        restore_best_weights=True
    )
    
    # Train model
    history = model.fit(
        X_train, y_train,
        validation_data=(X_val, y_val),
        epochs=20000,
        batch_size=batch_size,
        callbacks=[early_stopping],
        verbose=0
    )
    
    # Evaluate model
    X_all = np.vstack([X_train, X_val, X_test])
    y_all = np.concatenate([y_train, y_val, y_test])
    
    # Make predictions
    y_pred_train = model.predict(X_train, verbose=0)
    y_pred_val = model.predict(X_val, verbose=0)
    y_pred_test = model.predict(X_test, verbose=0)
    y_pred_all = model.predict(X_all, verbose=0)
    
    # Calculate MSE
    mse_train = np.mean((y_train - y_pred_train.flatten()) ** 2)
    mse_val = np.mean((y_val - y_pred_val.flatten()) ** 2)
    mse_test = np.mean((y_test - y_pred_test.flatten()) ** 2)
    mse_all = np.mean((y_all - y_pred_all.flatten()) ** 2)
    
    # Calculate R²
    r2_train = r2_score(y_train, y_pred_train)
    r2_val = r2_score(y_val, y_pred_val)
    r2_test = r2_score(y_test, y_pred_test)
    r2_all = r2_score(y_all, y_pred_all)
    
    return {
        'mse': {'train': mse_train, 'val': mse_val, 'test': mse_test, 'all': mse_all},
        'r2': {'train': r2_train, 'val': r2_val, 'test': r2_test, 'all': r2_all}
    }

# Load and prepare data
def prepare_data():
    # Load the data
    df = pd.read_csv('Body_Fat.csv')
    
    # Separate features and target
    X = df.drop('BodyFat', axis=1)
    y = df['BodyFat']
    
    # Scale the features
    scaler = MinMaxScaler()
    X_scaled = scaler.fit_transform(X)
    
    # Split the data
    X_train_val, X_test, y_train_val, y_test = train_test_split(
        X_scaled, y, test_size=0.2, random_state=42
    )
    X_train, X_val, y_train, y_val = train_test_split(
        X_train_val, y_train_val, test_size=0.25, random_state=42
    )
    
    return X_train, X_val, X_test, y_train, y_val, y_test

def run_experiments():
    X_train, X_val, X_test, y_train, y_val, y_test = prepare_data()
    
    # Hyperparameters to try
    hidden_neurons_options = [5, 10, 20]
    learning_rates = [0.001, 0.01, 0.1]
    batch_sizes = [16, 32, 64]
    seeds = [0, 42, 123]
    
    results = []
    
    for neurons in hidden_neurons_options:
        for lr in learning_rates:
            for batch_size in batch_sizes:
                for seed in seeds:
                    result = create_and_train_model(
                        X_train, X_val, X_test, y_train, y_val, y_test, 
                        neurons, lr, batch_size, seed
                    )
                    results.append({
                        'neurons': neurons,
                        'learning_rate': lr,
                        'batch_size': batch_size,
                        'seed': seed,
                        **result
                    })
                    
                    print(f"Neurons: {neurons}, Learning Rate: {lr}, Batch Size: {batch_size}, Seed: {seed}")
                    print(f"MSE - Train: {result['mse']['train']:.4f}, Val: {result['mse']['val']:.4f}, "
                          f"Test: {result['mse']['test']:.4f}, All: {result['mse']['all']:.4f}")
                    print(f"R² - Train: {result['r2']['train']:.4f}, Val: {result['r2']['val']:.4f}, "
                          f"Test: {result['r2']['test']:.4f}, All: {result['r2']['all']:.4f}")
                    print("-" * 80)
    
    # Find and print the best model based on test R²
    best_result = max(results, key=lambda x: x['r2']['test'])
    print("\nBest Model Configuration:")
    print(f"Neurons: {best_result['neurons']}")
    print(f"Learning Rate: {best_result['learning_rate']}")
    print(f"Batch Size: {best_result['batch_size']}")
    print(f"Seed: {best_result['seed']}")
    print(f"Test R²: {best_result['r2']['test']:.4f}")
    print(f"Test MSE: {best_result['mse']['test']:.4f}")
    
    return results, best_result

if __name__ == "__main__":
    results, best_result = run_experiments()
# Out:
# Neurons: 5, Learning Rate: 0.001, Batch Size: 16, Seed: 0
# MSE - Train: 1.1987, Val: 0.3188, Test: 0.6658, All: 0.9128
# R² - Train: 0.9845, Val: 0.9953, Test: 0.9857, All: 0.9869
# --------------------------------------------------------------------------------
# Neurons: 5, Learning Rate: 0.001, Batch Size: 16, Seed: 42
# MSE - Train: 1.0750, Val: 0.3454, Test: 0.4620, All: 0.8033
# R² - Train: 0.9861, Val: 0.9950, Test: 0.9901, All: 0.9885
# --------------------------------------------------------------------------------
# Neurons: 5, Learning Rate: 0.001, Batch Size: 16, Seed: 123
# MSE - Train: 1.1429, Val: 0.3626, Test: 0.5130, All: 0.8575
# R² - Train: 0.9853, Val: 0.9947, Test: 0.9890, All: 0.9877
# --------------------------------------------------------------------------------
# Neurons: 5, Learning Rate: 0.001, Batch Size: 32, Seed: 0
# MSE - Train: 1.2560, Val: 0.4044, Test: 0.4944, All: 0.9295
# R² - Train: 0.9838, Val: 0.9941, Test: 0.9894, All: 0.9867
# --------------------------------------------------------------------------------
# Neurons: 5, Learning Rate: 0.001, Batch Size: 32, Seed: 42
# MSE - Train: 1.3100, Val: 0.5140, Test: 0.9288, All: 1.0717
# R² - Train: 0.9831, Val: 0.9925, Test: 0.9800, All: 0.9846
# --------------------------------------------------------------------------------
# Neurons: 5, Learning Rate: 0.001, Batch Size: 32, Seed: 123
# MSE - Train: 1.1650, Val: 0.3487, Test: 0.4988, All: 0.8650
# R² - Train: 0.9850, Val: 0.9949, Test: 0.9893, All: 0.9876
# --------------------------------------------------------------------------------
# Neurons: 5, Learning Rate: 0.001, Batch Size: 64, Seed: 0
# MSE - Train: 0.9124, Val: 0.2714, Test: 0.5482, All: 0.7090
# R² - Train: 0.9882, Val: 0.9960, Test: 0.9882, All: 0.9898
# --------------------------------------------------------------------------------
# Neurons: 5, Learning Rate: 0.001, Batch Size: 64, Seed: 42
# MSE - Train: 1.2840, Val: 0.9607, Test: 0.8506, All: 1.1308
# R² - Train: 0.9834, Val: 0.9860, Test: 0.9817, All: 0.9838
# --------------------------------------------------------------------------------
# Neurons: 5, Learning Rate: 0.001, Batch Size: 64, Seed: 123
# MSE - Train: 1.2695, Val: 0.3220, Test: 0.4872, All: 0.9194
# R² - Train: 0.9836, Val: 0.9953, Test: 0.9895, All: 0.9868
# --------------------------------------------------------------------------------
# Neurons: 5, Learning Rate: 0.01, Batch Size: 16, Seed: 0
# MSE - Train: 0.9893, Val: 0.1997, Test: 0.5306, All: 0.7367
# R² - Train: 0.9872, Val: 0.9971, Test: 0.9886, All: 0.9894
# --------------------------------------------------------------------------------
# Neurons: 5, Learning Rate: 0.01, Batch Size: 16, Seed: 42
# MSE - Train: 1.2197, Val: 0.4658, Test: 0.4911, All: 0.9196
# R² - Train: 0.9843, Val: 0.9932, Test: 0.9894, All: 0.9868
# --------------------------------------------------------------------------------
# Neurons: 5, Learning Rate: 0.01, Batch Size: 16, Seed: 123
# MSE - Train: 1.0863, Val: 0.2741, Test: 0.6692, All: 0.8375
# R² - Train: 0.9860, Val: 0.9960, Test: 0.9856, All: 0.9880
# --------------------------------------------------------------------------------
# Neurons: 5, Learning Rate: 0.01, Batch Size: 32, Seed: 0
# MSE - Train: 1.0935, Val: 0.5545, Test: 0.9312, All: 0.9516
# R² - Train: 0.9859, Val: 0.9919, Test: 0.9800, All: 0.9864
# --------------------------------------------------------------------------------
# Neurons: 5, Learning Rate: 0.01, Batch Size: 32, Seed: 42
# MSE - Train: 0.7963, Val: 0.4571, Test: 1.2104, All: 0.8115
# R² - Train: 0.9897, Val: 0.9933, Test: 0.9740, All: 0.9884
# --------------------------------------------------------------------------------
# Neurons: 5, Learning Rate: 0.01, Batch Size: 32, Seed: 123
# MSE - Train: 1.2482, Val: 0.2791, Test: 0.9031, All: 0.9822
# R² - Train: 0.9839, Val: 0.9959, Test: 0.9806, All: 0.9859
# --------------------------------------------------------------------------------
# Neurons: 5, Learning Rate: 0.01, Batch Size: 64, Seed: 0
# MSE - Train: 1.1550, Val: 0.3417, Test: 0.4767, All: 0.8531
# R² - Train: 0.9851, Val: 0.9950, Test: 0.9898, All: 0.9878
# --------------------------------------------------------------------------------
# Neurons: 5, Learning Rate: 0.01, Batch Size: 64, Seed: 42
# MSE - Train: 1.6858, Val: 1.2274, Test: 1.2554, All: 1.5059
# R² - Train: 0.9783, Val: 0.9821, Test: 0.9730, All: 0.9784
# --------------------------------------------------------------------------------
# Neurons: 5, Learning Rate: 0.01, Batch Size: 64, Seed: 123
# MSE - Train: 1.1566, Val: 0.3901, Test: 0.6033, All: 0.8895
# R² - Train: 0.9851, Val: 0.9943, Test: 0.9870, All: 0.9872
# --------------------------------------------------------------------------------
# Neurons: 5, Learning Rate: 0.1, Batch Size: 16, Seed: 0
# MSE - Train: 1.8250, Val: 0.9235, Test: 0.9392, All: 1.4633
# R² - Train: 0.9765, Val: 0.9865, Test: 0.9798, All: 0.9790
# --------------------------------------------------------------------------------
# Neurons: 5, Learning Rate: 0.1, Batch Size: 16, Seed: 42
# MSE - Train: 1.3300, Val: 0.7596, Test: 2.4407, All: 1.4393
# R² - Train: 0.9829, Val: 0.9889, Test: 0.9475, All: 0.9794
# --------------------------------------------------------------------------------
# Neurons: 5, Learning Rate: 0.1, Batch Size: 16, Seed: 123
# MSE - Train: 2.0834, Val: 0.6568, Test: 0.7197, All: 1.5187
# R² - Train: 0.9731, Val: 0.9904, Test: 0.9845, All: 0.9782
# --------------------------------------------------------------------------------
# Neurons: 5, Learning Rate: 0.1, Batch Size: 32, Seed: 0
# MSE - Train: 1.8210, Val: 0.7916, Test: 1.0234, All: 1.4512
# R² - Train: 0.9765, Val: 0.9884, Test: 0.9780, All: 0.9792
# --------------------------------------------------------------------------------
# Neurons: 5, Learning Rate: 0.1, Batch Size: 32, Seed: 42
# MSE - Train: 2.9473, Val: 1.7145, Test: 1.7374, All: 2.4530
# R² - Train: 0.9620, Val: 0.9750, Test: 0.9627, All: 0.9648
# --------------------------------------------------------------------------------
# Neurons: 5, Learning Rate: 0.1, Batch Size: 32, Seed: 123
# MSE - Train: 0.8252, Val: 0.5557, Test: 1.5717, All: 0.9217
# R² - Train: 0.9894, Val: 0.9919, Test: 0.9662, All: 0.9868
# --------------------------------------------------------------------------------
# Neurons: 5, Learning Rate: 0.1, Batch Size: 64, Seed: 0
# MSE - Train: 2.0670, Val: 0.9568, Test: 1.1153, All: 1.6497
# R² - Train: 0.9734, Val: 0.9860, Test: 0.9760, All: 0.9764
# --------------------------------------------------------------------------------
# Neurons: 5, Learning Rate: 0.1, Batch Size: 64, Seed: 42
# MSE - Train: 1.9980, Val: 1.0775, Test: 1.2562, All: 1.6616
# R² - Train: 0.9742, Val: 0.9843, Test: 0.9730, All: 0.9762
# --------------------------------------------------------------------------------
# Neurons: 5, Learning Rate: 0.1, Batch Size: 64, Seed: 123
# MSE - Train: 1.6000, Val: 0.6567, Test: 0.5662, All: 1.1999
# R² - Train: 0.9794, Val: 0.9904, Test: 0.9878, All: 0.9828
# --------------------------------------------------------------------------------
# Neurons: 10, Learning Rate: 0.001, Batch Size: 16, Seed: 0
# MSE - Train: 1.0102, Val: 0.3204, Test: 0.4458, All: 0.7564
# R² - Train: 0.9870, Val: 0.9953, Test: 0.9904, All: 0.9892
# --------------------------------------------------------------------------------
# Neurons: 10, Learning Rate: 0.001, Batch Size: 16, Seed: 42
# MSE - Train: 0.9455, Val: 0.2657, Test: 0.4394, All: 0.7055
# R² - Train: 0.9878, Val: 0.9961, Test: 0.9906, All: 0.9899
# --------------------------------------------------------------------------------
# Neurons: 10, Learning Rate: 0.001, Batch Size: 16, Seed: 123
# MSE - Train: 1.1431, Val: 0.3735, Test: 0.6099, All: 0.8794
# R² - Train: 0.9853, Val: 0.9945, Test: 0.9869, All: 0.9874
# --------------------------------------------------------------------------------
# Neurons: 10, Learning Rate: 0.001, Batch Size: 32, Seed: 0
# MSE - Train: 0.7446, Val: 0.3071, Test: 0.6961, All: 0.6462
# R² - Train: 0.9904, Val: 0.9955, Test: 0.9850, All: 0.9907
# --------------------------------------------------------------------------------
# Neurons: 10, Learning Rate: 0.001, Batch Size: 32, Seed: 42
# MSE - Train: 0.7842, Val: 0.3012, Test: 0.4833, All: 0.6255
# R² - Train: 0.9899, Val: 0.9956, Test: 0.9896, All: 0.9910
# --------------------------------------------------------------------------------
# Neurons: 10, Learning Rate: 0.001, Batch Size: 32, Seed: 123
# MSE - Train: 1.2150, Val: 0.3851, Test: 0.5195, All: 0.9063
# R² - Train: 0.9843, Val: 0.9944, Test: 0.9888, All: 0.9870
# --------------------------------------------------------------------------------
# Neurons: 10, Learning Rate: 0.001, Batch Size: 64, Seed: 0
# MSE - Train: 0.8078, Val: 0.2501, Test: 0.6823, All: 0.6695
# R² - Train: 0.9896, Val: 0.9963, Test: 0.9853, All: 0.9904
# --------------------------------------------------------------------------------
# Neurons: 10, Learning Rate: 0.001, Batch Size: 64, Seed: 42
# MSE - Train: 0.8531, Val: 0.6835, Test: 1.5022, All: 0.9502
# R² - Train: 0.9890, Val: 0.9900, Test: 0.9677, All: 0.9864
# --------------------------------------------------------------------------------
# Neurons: 10, Learning Rate: 0.001, Batch Size: 64, Seed: 123
# MSE - Train: 1.2528, Val: 0.4063, Test: 0.5298, All: 0.9352
# R² - Train: 0.9838, Val: 0.9941, Test: 0.9886, All: 0.9866
# --------------------------------------------------------------------------------
# Neurons: 10, Learning Rate: 0.01, Batch Size: 16, Seed: 0
# MSE - Train: 1.0427, Val: 0.2390, Test: 0.5467, All: 0.7797
# R² - Train: 0.9866, Val: 0.9965, Test: 0.9882, All: 0.9888
# --------------------------------------------------------------------------------
# Neurons: 10, Learning Rate: 0.01, Batch Size: 16, Seed: 42
# MSE - Train: 0.9443, Val: 0.2287, Test: 0.7422, All: 0.7586
# R² - Train: 0.9878, Val: 0.9967, Test: 0.9840, All: 0.9891
# --------------------------------------------------------------------------------
# Neurons: 10, Learning Rate: 0.01, Batch Size: 16, Seed: 123
# MSE - Train: 1.1389, Val: 0.2645, Test: 0.5540, All: 0.8436
# R² - Train: 0.9853, Val: 0.9961, Test: 0.9881, All: 0.9879
# --------------------------------------------------------------------------------
# Neurons: 10, Learning Rate: 0.01, Batch Size: 32, Seed: 0
# MSE - Train: 1.0581, Val: 0.2841, Test: 0.4353, All: 0.7754
# R² - Train: 0.9864, Val: 0.9959, Test: 0.9906, All: 0.9889
# --------------------------------------------------------------------------------
# Neurons: 10, Learning Rate: 0.01, Batch Size: 32, Seed: 42
# MSE - Train: 0.6961, Val: 0.3243, Test: 0.8400, All: 0.6500
# R² - Train: 0.9910, Val: 0.9953, Test: 0.9819, All: 0.9907
# --------------------------------------------------------------------------------
# Neurons: 10, Learning Rate: 0.01, Batch Size: 32, Seed: 123
# MSE - Train: 0.8582, Val: 0.1913, Test: 0.6566, All: 0.6825
# R² - Train: 0.9889, Val: 0.9972, Test: 0.9859, All: 0.9902
# --------------------------------------------------------------------------------
# Neurons: 10, Learning Rate: 0.01, Batch Size: 64, Seed: 0
# MSE - Train: 1.0499, Val: 0.3073, Test: 0.4467, All: 0.7776
# R² - Train: 0.9865, Val: 0.9955, Test: 0.9904, All: 0.9889
# --------------------------------------------------------------------------------
# Neurons: 10, Learning Rate: 0.01, Batch Size: 64, Seed: 42
# MSE - Train: 0.8086, Val: 0.4833, Test: 1.0488, All: 0.7914
# R² - Train: 0.9896, Val: 0.9929, Test: 0.9775, All: 0.9887
# --------------------------------------------------------------------------------
# Neurons: 10, Learning Rate: 0.01, Batch Size: 64, Seed: 123
# MSE - Train: 1.0028, Val: 0.2069, Test: 0.3181, All: 0.7031
# R² - Train: 0.9871, Val: 0.9970, Test: 0.9932, All: 0.9899
# --------------------------------------------------------------------------------
# Neurons: 10, Learning Rate: 0.1, Batch Size: 16, Seed: 0
# MSE - Train: 1.1128, Val: 0.4649, Test: 0.6837, All: 0.8948
# R² - Train: 0.9857, Val: 0.9932, Test: 0.9853, All: 0.9872
# --------------------------------------------------------------------------------
# Neurons: 10, Learning Rate: 0.1, Batch Size: 16, Seed: 42
# MSE - Train: 1.2873, Val: 0.9644, Test: 0.7686, All: 1.1170
# R² - Train: 0.9834, Val: 0.9859, Test: 0.9835, All: 0.9840
# --------------------------------------------------------------------------------
# Neurons: 10, Learning Rate: 0.1, Batch Size: 16, Seed: 123
# MSE - Train: 0.7507, Val: 0.4346, Test: 0.7921, All: 0.6951
# R² - Train: 0.9903, Val: 0.9937, Test: 0.9830, All: 0.9900
# --------------------------------------------------------------------------------
# Neurons: 10, Learning Rate: 0.1, Batch Size: 32, Seed: 0
# MSE - Train: 1.3810, Val: 0.4558, Test: 0.5633, All: 1.0283
# R² - Train: 0.9822, Val: 0.9933, Test: 0.9879, All: 0.9853
# --------------------------------------------------------------------------------
# Neurons: 10, Learning Rate: 0.1, Batch Size: 32, Seed: 42
# MSE - Train: 0.9031, Val: 0.6617, Test: 2.4413, All: 1.1656
# R² - Train: 0.9884, Val: 0.9903, Test: 0.9475, All: 0.9833
# --------------------------------------------------------------------------------
# Neurons: 10, Learning Rate: 0.1, Batch Size: 32, Seed: 123
# MSE - Train: 0.7606, Val: 0.2995, Test: 0.4341, All: 0.6012
# R² - Train: 0.9902, Val: 0.9956, Test: 0.9907, All: 0.9914
# --------------------------------------------------------------------------------
# Neurons: 10, Learning Rate: 0.1, Batch Size: 64, Seed: 0
# MSE - Train: 0.8390, Val: 0.3638, Test: 0.3408, All: 0.6420
# R² - Train: 0.9892, Val: 0.9947, Test: 0.9927, All: 0.9908
# --------------------------------------------------------------------------------
# Neurons: 10, Learning Rate: 0.1, Batch Size: 64, Seed: 42
# MSE - Train: 0.7650, Val: 0.5730, Test: 0.5666, All: 0.6860
# R² - Train: 0.9901, Val: 0.9916, Test: 0.9878, All: 0.9902
# --------------------------------------------------------------------------------
# Neurons: 10, Learning Rate: 0.1, Batch Size: 64, Seed: 123
# MSE - Train: 1.0438, Val: 0.3098, Test: 0.7521, All: 0.8362
# R² - Train: 0.9865, Val: 0.9955, Test: 0.9838, All: 0.9880
# --------------------------------------------------------------------------------
# Neurons: 20, Learning Rate: 0.001, Batch Size: 16, Seed: 0
# MSE - Train: 1.1003, Val: 0.3388, Test: 0.5264, All: 0.8300
# R² - Train: 0.9858, Val: 0.9951, Test: 0.9887, All: 0.9881
# --------------------------------------------------------------------------------
# Neurons: 20, Learning Rate: 0.001, Batch Size: 16, Seed: 42
# MSE - Train: 1.1503, Val: 0.4655, Test: 0.5757, All: 0.8954
# R² - Train: 0.9852, Val: 0.9932, Test: 0.9876, All: 0.9872
# --------------------------------------------------------------------------------
# Neurons: 20, Learning Rate: 0.001, Batch Size: 16, Seed: 123
# MSE - Train: 1.1414, Val: 0.4347, Test: 0.5354, All: 0.8757
# R² - Train: 0.9853, Val: 0.9936, Test: 0.9885, All: 0.9874
# --------------------------------------------------------------------------------
# Neurons: 20, Learning Rate: 0.001, Batch Size: 32, Seed: 0
# MSE - Train: 0.7806, Val: 0.3486, Test: 0.3862, All: 0.6134
# R² - Train: 0.9899, Val: 0.9949, Test: 0.9917, All: 0.9912
# --------------------------------------------------------------------------------
# Neurons: 20, Learning Rate: 0.001, Batch Size: 32, Seed: 42
# MSE - Train: 0.6978, Val: 0.3204, Test: 0.4389, All: 0.5690
# R² - Train: 0.9910, Val: 0.9953, Test: 0.9906, All: 0.9918
# --------------------------------------------------------------------------------
# Neurons: 20, Learning Rate: 0.001, Batch Size: 32, Seed: 123
# MSE - Train: 0.7106, Val: 0.2784, Test: 0.5357, All: 0.5877
# R² - Train: 0.9908, Val: 0.9959, Test: 0.9885, All: 0.9916
# --------------------------------------------------------------------------------
# Neurons: 20, Learning Rate: 0.001, Batch Size: 64, Seed: 0
# MSE - Train: 0.6381, Val: 0.2405, Test: 0.3766, All: 0.5047
# R² - Train: 0.9918, Val: 0.9965, Test: 0.9919, All: 0.9928
# --------------------------------------------------------------------------------
# Neurons: 20, Learning Rate: 0.001, Batch Size: 64, Seed: 42
# MSE - Train: 0.8422, Val: 0.4980, Test: 0.5642, All: 0.7163
# R² - Train: 0.9891, Val: 0.9927, Test: 0.9879, All: 0.9897
# --------------------------------------------------------------------------------
# Neurons: 20, Learning Rate: 0.001, Batch Size: 64, Seed: 123
# MSE - Train: 1.0699, Val: 0.2981, Test: 0.7223, All: 0.8433
# R² - Train: 0.9862, Val: 0.9956, Test: 0.9845, All: 0.9879
# --------------------------------------------------------------------------------
# Neurons: 20, Learning Rate: 0.01, Batch Size: 16, Seed: 0
# MSE - Train: 0.8548, Val: 0.2492, Test: 0.5924, All: 0.6791
# R² - Train: 0.9890, Val: 0.9964, Test: 0.9873, All: 0.9903
# --------------------------------------------------------------------------------
# Neurons: 20, Learning Rate: 0.01, Batch Size: 16, Seed: 42
# MSE - Train: 0.9221, Val: 0.2674, Test: 0.8479, All: 0.7746
# R² - Train: 0.9881, Val: 0.9961, Test: 0.9818, All: 0.9889
# --------------------------------------------------------------------------------
# Neurons: 20, Learning Rate: 0.01, Batch Size: 16, Seed: 123
# MSE - Train: 0.6602, Val: 0.2791, Test: 0.6232, All: 0.5756
# R² - Train: 0.9915, Val: 0.9959, Test: 0.9866, All: 0.9917
# --------------------------------------------------------------------------------
# Neurons: 20, Learning Rate: 0.01, Batch Size: 32, Seed: 0
# MSE - Train: 0.8444, Val: 0.1955, Test: 0.6149, All: 0.6666
# R² - Train: 0.9891, Val: 0.9971, Test: 0.9868, All: 0.9904
# --------------------------------------------------------------------------------
# Neurons: 20, Learning Rate: 0.01, Batch Size: 32, Seed: 42
# MSE - Train: 0.7796, Val: 0.2390, Test: 0.4254, All: 0.5985
# R² - Train: 0.9899, Val: 0.9965, Test: 0.9909, All: 0.9914
# --------------------------------------------------------------------------------
# Neurons: 20, Learning Rate: 0.01, Batch Size: 32, Seed: 123
# MSE - Train: 0.8022, Val: 0.2342, Test: 0.7399, All: 0.6746
# R² - Train: 0.9897, Val: 0.9966, Test: 0.9841, All: 0.9903
# --------------------------------------------------------------------------------
# Neurons: 20, Learning Rate: 0.01, Batch Size: 64, Seed: 0
# MSE - Train: 0.8499, Val: 0.2604, Test: 0.4870, All: 0.6572
# R² - Train: 0.9890, Val: 0.9962, Test: 0.9895, All: 0.9906
# --------------------------------------------------------------------------------
# Neurons: 20, Learning Rate: 0.01, Batch Size: 64, Seed: 42
# MSE - Train: 0.7177, Val: 0.4916, Test: 0.4901, All: 0.6259
# R² - Train: 0.9907, Val: 0.9928, Test: 0.9895, All: 0.9910
# --------------------------------------------------------------------------------
# Neurons: 20, Learning Rate: 0.01, Batch Size: 64, Seed: 123
# MSE - Train: 0.8867, Val: 0.1940, Test: 0.3797, All: 0.6439
# R² - Train: 0.9886, Val: 0.9972, Test: 0.9918, All: 0.9908
# --------------------------------------------------------------------------------
# Neurons: 20, Learning Rate: 0.1, Batch Size: 16, Seed: 0
# MSE - Train: 0.7498, Val: 0.4291, Test: 0.8638, All: 0.7079
# R² - Train: 0.9903, Val: 0.9937, Test: 0.9814, All: 0.9899
# --------------------------------------------------------------------------------
# Neurons: 20, Learning Rate: 0.1, Batch Size: 16, Seed: 42
# MSE - Train: 1.3475, Val: 0.4563, Test: 0.4972, All: 0.9951
# R² - Train: 0.9826, Val: 0.9933, Test: 0.9893, All: 0.9857
# --------------------------------------------------------------------------------
# Neurons: 20, Learning Rate: 0.1, Batch Size: 16, Seed: 123
# MSE - Train: 0.4999, Val: 0.3922, Test: 0.5596, All: 0.4902
# R² - Train: 0.9936, Val: 0.9943, Test: 0.9880, All: 0.9930
# --------------------------------------------------------------------------------
# Neurons: 20, Learning Rate: 0.1, Batch Size: 32, Seed: 0
# MSE - Train: 1.0214, Val: 0.3456, Test: 0.5629, All: 0.7919
# R² - Train: 0.9868, Val: 0.9950, Test: 0.9879, All: 0.9886
# --------------------------------------------------------------------------------
# Neurons: 20, Learning Rate: 0.1, Batch Size: 32, Seed: 42
# MSE - Train: 1.4775, Val: 0.4697, Test: 1.5788, All: 1.2941
# R² - Train: 0.9810, Val: 0.9931, Test: 0.9661, All: 0.9814
# --------------------------------------------------------------------------------
# Neurons: 20, Learning Rate: 0.1, Batch Size: 32, Seed: 123
# MSE - Train: 0.8223, Val: 0.3914, Test: 0.2723, All: 0.6238
# R² - Train: 0.9894, Val: 0.9943, Test: 0.9941, All: 0.9911
# --------------------------------------------------------------------------------
# Neurons: 20, Learning Rate: 0.1, Batch Size: 64, Seed: 0
# MSE - Train: 0.9063, Val: 0.2415, Test: 0.6823, All: 0.7264
# R² - Train: 0.9883, Val: 0.9965, Test: 0.9853, All: 0.9896
# --------------------------------------------------------------------------------
# Neurons: 20, Learning Rate: 0.1, Batch Size: 64, Seed: 42
# MSE - Train: 0.6423, Val: 0.5924, Test: 0.4701, All: 0.5973
# R² - Train: 0.9917, Val: 0.9913, Test: 0.9899, All: 0.9914
# --------------------------------------------------------------------------------
# Neurons: 20, Learning Rate: 0.1, Batch Size: 64, Seed: 123
# MSE - Train: 1.2757, Val: 0.3521, Test: 0.7944, All: 0.9914
# R² - Train: 0.9836, Val: 0.9949, Test: 0.9829, All: 0.9858
# --------------------------------------------------------------------------------
#
# Best Model Configuration:
# Neurons: 20
# Learning Rate: 0.1
# Batch Size: 32
# Seed: 123
# Test R²: 0.9941
# Test MSE: 0.2723
